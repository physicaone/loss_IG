# %%
import time
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import math
import time
import multiprocessing
from multiprocessing import Pool

# %%
# cpu_count=multiprocessing.cpu_count()
cpu_count = 2

# %%
def stround(x):
    c = np.floor(x)
    return c + ((x - c) > np.random.rand())

def activate(x):
    sigma = 1/ (1 + np.exp(-x))
    return sigma

def energy(a, b, W, visible_vector):
    '''
    Enerexponentf Restricted Bolztmann machine for given parameters.
    CAUTION: a, b must be column vector. 
    '''
    #W.shape = (n_hid, 784)
    l = len(b) #n_hid
    v = visible_vector.reshape(784,1) #v.shape = (784,1)
    a, b = a.reshape(784,1), b.reshape(l,1) #both are column vector
    h = stround(activate(np.matmul(v.T,W.T).T + b)) #column vector
    e = -np.dot(a.T,v) - np.dot(b.T,h) - np.matmul(np.matmul(v.T, W.T), h) #a scalar
    
    return e

def initial(lattice_size):
    '''
    Making random configuration which consists of 0/1.
    '''
    config = np.random.randint(2, size = (lattice_size, lattice_size))
    return config

def function1(index_E1):
    global ini_index
    for k in range(len(index_E1)-1):
        c_1, c_2 = index_E1[k][1], index_E1[k+1][1]
        if e >= c_1 and e <= (c_1 + c_2)/2:
            ini_index = index_E1[k][0]
            break
        elif e >= (c_1 + c_2)/2 and e <= c_2: 
            ini_index = index_E1[k+1][0]
            break

def function2(index_E2):
    global cha_index
    for k in range(len(index_E2)-1):
        c_1, c_2 = index_E2[k][1], index_E2[k+1][1]
        if ee >= c_1 and ee <= (c_1 + c_2)/2:
            cha_index = index_E2[k][0]
            break
        elif ee >= (c_1 + c_2)/2 and ee <= c_2: 
            cha_index = index_E2[k+1][0]
            break
            
def multi_processing(index_E, function0):
    chunks = [index_E[i::cpu_count] for i in range(cpu_count)]
    pool = Pool(processes=cpu_count)
    result = pool.map_async(function0, chunks)
#     while not result.ready():
#         time.sleep(0.5)

# %%
def wang_landau(a,b,W): #lattice_size = 28 for MNIST RBM
    '''
    Trained model의 parameters를 넣고, sample_size만큼의 spin flip을 "시도"합니다.
    Energy space를 1간격으로 uniform하게 나눕니다.
    '''
    config = initial(28) #초기 이미지 만들기
    
    
    ######## 이 부분은 경험적으로 얻은 값을 대입하시면 됩니다.####################
    E_min=1600
    E_max=3500
    E = np.linspace(E_min, E_max, 400)
    ##############################################################################

    e = energy(a, b, W, config) #initial configuration의 energy입니다.
    ln_gE = np.zeros(len(E))
    Histogram = np.zeros(len(E))
    log_modi_factor = 1
    
    index_E1, index_E2 = [], []
    ini_index, cha_index = 0, 0
    
    count_flat, count_sweep = 0, 0

    for i in enumerate(E): 
        index_E1.append(i)
    for j in enumerate(E): 
        index_E2.append(j)
    
    while count_flat <= 27:
        count_sweep += 1
        for i in range(28):
            for j in range(28):
                s = config[i,j]

                #spin flip
                #count_flip += 1
                if s == 0:
                    s = 1
                else:
                    s = 0
                config[i,j] = s
                ee = energy(a, b, W, config) #spin을 하나 flip한 사진의 에너지를 구합니다.

#                 for k in range(len(index_E1)-1):
#                     c_1, c_2 = index_E1[k][1], index_E1[k+1][1]
#                     if e >= c_1 and e <= (c_1 + c_2)/2:
#                         ini_index = index_E1[k][0]
#                         break
#                     elif e >= (c_1 + c_2)/2 and e <= c_2: 
#                         ini_index = index_E1[k+1][0]
#                         break

#                 for k in range(len(index_E2)-1):
#                     c_1, c_2 = index_E2[k][1], index_E2[k+1][1]
#                     if ee >= c_1 and ee <= (c_1 + c_2)/2:
#                         cha_index = index_E2[k][0]
#                         break
#                     elif ee >= (c_1 + c_2)/2 and ee <= c_2: 
#                         cha_index = index_E2[k+1][0]
# #                         break
#                 multi_processing(index_E1, e)
#                 multi_processing(index_E2, ee)
                multi_processing(index_E1, function1)
                multi_processing(index_E2, function2)
                p = np.exp(ln_gE[ini_index] - ln_gE[cha_index])
                if p > np.random.rand():
                    s = s #keeps flipped value
                    Histogram[cha_index] += 1
                    ln_gE[cha_index] += log_modi_factor
                    e = ee
                else:
                    if s == 0:
                        s = 1
                    else:
                        s = 0 
                    config[i,j] = s #spin flip is rejected
                    Histogram[ini_index] += 1
                    ln_gE[ini_index] += log_modi_factor
                    e = e

        #Is the Histogram flat?
        if count_sweep % 10000 == 0:
            Havg = np.mean(Histogram)
            Hmin = min(Histogram)
            print(Histogram)
            if Havg*0.80 <= Hmin:
                Histogram = np.zeros_like(E)
                log_modi_factor *= 0.5
                count_flat += 1
                print(f"{count_flat}")
    return ln_gE

# %% [markdown]
# Partition function $Z = \sum_{E} g(E) e^{-E}$. <br>
# Free energy is defined as $F = - \text{log}{Z}$. <br>

# %% [markdown]
# ## 필요한 parameter를 불러오시면 됩니다.

# %%
#여기서 필요하신 값들을 대입하시면 됩니다.
a = pd.read_pickle('parameters/n_hid=4_vol_12000_bias_v.pkl')
b = pd.read_pickle('parameters/n_hid=4_vol_12000_bias_h.pkl')
W = pd.read_pickle('parameters/n_hid=4_vol_12000_weight.pkl')

# %%
start = time.time()
lngE = wang_landau(a,b,W)
end = time.time() - start
print(f"Takes {end/60} min")
# Out:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Process ForkPoolWorker-236:
# Process ForkPoolWorker-219:
# Process ForkPoolWorker-197:
# Process ForkPoolWorker-204:
# Process ForkPoolWorker-193:
# Process ForkPoolWorker-187:
# Process ForkPoolWorker-186:
# Process ForkPoolWorker-189:
# Process ForkPoolWorker-179:
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-170:
# Process ForkPoolWorker-165:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-159:
# Process ForkPoolWorker-154:
# Process ForkPoolWorker-153:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-142:
# Process ForkPoolWorker-156:
# Process ForkPoolWorker-151:
# Process ForkPoolWorker-137:
# Process ForkPoolWorker-256:
# Process ForkPoolWorker-9:
# Process ForkPoolWorker-55:
# Process ForkPoolWorker-57:
# Process ForkPoolWorker-5:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-24:
# Process ForkPoolWorker-7:
# Process ForkPoolWorker-50:
# Process ForkPoolWorker-54:
# Process ForkPoolWorker-41:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-48:
# Process ForkPoolWorker-93:
# Process ForkPoolWorker-104:
# Process ForkPoolWorker-81:
# Process ForkPoolWorker-91:
# Process ForkPoolWorker-105:
# Process ForkPoolWorker-70:
# Process ForkPoolWorker-89:
# Process ForkPoolWorker-455:
# Process ForkPoolWorker-313:
# Process ForkPoolWorker-523:
# Process ForkPoolWorker-490:
# Process ForkPoolWorker-572:
# Process ForkPoolWorker-58:
# Process ForkPoolWorker-83:
# Process ForkPoolWorker-85:
# Process ForkPoolWorker-77:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-10:
# Process ForkPoolWorker-114:
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-521:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-328:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-391:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-371:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-573:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-477:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-45822db1547b> in <module>
#       1 start = time.time()
# ----> 2 lngE = wang_landau(a,b,W)
#       3 end = time.time() - start
#       4 print(f"Takes {end/60} min")
#
# <ipython-input-12-b0245863c7ad> in wang_landau(a, b, W)
#      63 #                 multi_processing(index_E2, ee)
#      64                 multi_processing(index_E1, function1)
# ---> 65                 multi_processing(index_E2, function2)
#      66                 p = np.exp(ln_gE[ini_index] - ln_gE[cha_index])
#      67                 if p > np.random.rand():
#
# <ipython-input-11-07a0e19dbaa9> in multi_processing(index_E, function0)
#      52 def multi_processing(index_E, function0):
#      53     chunks = [index_E[i::cpu_count] for i in range(cpu_count)]
# ---> 54     pool = Pool(processes=cpu_count)
#      55     result = pool.map_async(function0, chunks)
#      56 #     while not result.ready():
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/context.py in Pool(self, processes, initializer, initargs, maxtasksperchild)
#     117         from .pool import Pool
#     118         return Pool(processes, initializer, initargs, maxtasksperchild,
# --> 119                     context=self.get_context())
#     120
#     121     def RawValue(self, typecode_or_type, *args):
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in __init__(self, processes, initializer, initargs, maxtasksperchild, context)
#     174         self._processes = processes
#     175         self._pool = []
# --> 176         self._repopulate_pool()
#     177
#     178         self._worker_handler = threading.Thread(
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/pool.py in _repopulate_pool(self)
#     237                             )
#     238             self._pool.append(w)
# --> 239             w.name = w.name.replace('Process', 'PoolWorker')
#     240             w.daemon = True
#     241             w.start()
#
# ~/opt/anaconda3/lib/python3.7/multiprocessing/process.py in name(self)
#     180     @property
#     181     def name(self):
# --> 182         return self._name
#     183
#     184     @name.setter
#
# KeyboardInterrupt:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-524:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-494:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-155:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
# Process ForkPoolWorker-352:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-28:
# Process ForkPoolWorker-29:
# Process ForkPoolWorker-474:
# Process ForkPoolWorker-456:
# Process ForkPoolWorker-317:
# Process ForkPoolWorker-111:
# Process ForkPoolWorker-76:
# Process ForkPoolWorker-95:
# Process ForkPoolWorker-113:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-112:
# Process ForkPoolWorker-74:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-25:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-8:
# Process ForkPoolWorker-67:
# Process ForkPoolWorker-353:
# Process ForkPoolWorker-461:
# Process ForkPoolWorker-514:
# Process ForkPoolWorker-433:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-20:
# Process ForkPoolWorker-56:
# Process ForkPoolWorker-1:
# Process ForkPoolWorker-3:
# Process ForkPoolWorker-6:
# Process ForkPoolWorker-78:
# Process ForkPoolWorker-64:
# Process ForkPoolWorker-52:
# Process ForkPoolWorker-149:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-4:
# Process ForkPoolWorker-2:
# Process ForkPoolWorker-117:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-130:
# Process ForkPoolWorker-259:
# Process ForkPoolWorker-60:
# Process ForkPoolWorker-452:
# Process ForkPoolWorker-407:
# Process ForkPoolWorker-451:
# Process ForkPoolWorker-518:
# Process ForkPoolWorker-260:
# Process ForkPoolWorker-482:
# Process ForkPoolWorker-18:
# Process ForkPoolWorker-19:
# Process ForkPoolWorker-26:
# Process ForkPoolWorker-605:
# Process ForkPoolWorker-21:
# Process ForkPoolWorker-17:
# Process ForkPoolWorker-16:
# Process ForkPoolWorker-15:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-14:
# Process ForkPoolWorker-580:
# Process ForkPoolWorker-22:
# Process ForkPoolWorker-80:
# Process ForkPoolWorker-100:
# Process ForkPoolWorker-59:
# Process ForkPoolWorker-61:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-27:
# Process ForkPoolWorker-73:
# Process ForkPoolWorker-102:
# Process ForkPoolWorker-138:
# Process ForkPoolWorker-88:
# Process ForkPoolWorker-203:
# Process ForkPoolWorker-434:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-228:
# Process ForkPoolWorker-216:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-150:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-446:
# Process ForkPoolWorker-333:
# Process ForkPoolWorker-613:
# Process ForkPoolWorker-520:
# Process ForkPoolWorker-390:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-297:
# Process ForkPoolWorker-559:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-392:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-160:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-566:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-346:
# Process ForkPoolWorker-595:
# Process ForkPoolWorker-535:
# Traceback (most recent call last):
# Process ForkPoolWorker-512:
# Traceback (most recent call last):
# Process ForkPoolWorker-525:
# Process ForkPoolWorker-568:
# Process ForkPoolWorker-513:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-63:
# Traceback (most recent call last):
# Process ForkPoolWorker-94:
# Process ForkPoolWorker-124:
# Process ForkPoolWorker-82:
# Process ForkPoolWorker-71:
# Process ForkPoolWorker-168:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-303:
# Process ForkPoolWorker-261:
# Traceback (most recent call last):
# Process ForkPoolWorker-510:
# Traceback (most recent call last):
# Process ForkPoolWorker-509:
# Process ForkPoolWorker-515:
# Process ForkPoolWorker-507:
# Process ForkPoolWorker-87:
# Process ForkPoolWorker-75:
# Traceback (most recent call last):
# Process ForkPoolWorker-412:
# Process ForkPoolWorker-321:
# Process ForkPoolWorker-571:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-536:
# Process ForkPoolWorker-493:
# Process ForkPoolWorker-295:
# Process ForkPoolWorker-304:
# Process ForkPoolWorker-262:
# Process ForkPoolWorker-473:
# Process ForkPoolWorker-152:
# Process ForkPoolWorker-405:
# Process ForkPoolWorker-591:
# Traceback (most recent call last):
# Process ForkPoolWorker-418:
# Process ForkPoolWorker-413:
# Process ForkPoolWorker-358:
# Traceback (most recent call last):
# Process ForkPoolWorker-561:
# Traceback (most recent call last):
# Process ForkPoolWorker-66:
# Process ForkPoolWorker-374:
# Process ForkPoolWorker-342:
# Traceback (most recent call last):
# Process ForkPoolWorker-599:
# Traceback (most recent call last):
# Process ForkPoolWorker-171:
# Process ForkPoolWorker-90:
# Process ForkPoolWorker-68:
# Process ForkPoolWorker-429:
# Traceback (most recent call last):
# Process ForkPoolWorker-601:
# Process ForkPoolWorker-615:
# Process ForkPoolWorker-609:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-110:
# Process ForkPoolWorker-543:
# Process ForkPoolWorker-549:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-421:
# Process ForkPoolWorker-423:
# Process ForkPoolWorker-65:
# Process ForkPoolWorker-441:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-627:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-569:
# Process ForkPoolWorker-588:
# Process ForkPoolWorker-541:
# Process ForkPoolWorker-554:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
# Process ForkPoolWorker-205:
# Process ForkPoolWorker-200:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-241:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-435:
# Process ForkPoolWorker-242:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Process ForkPoolWorker-623:
# Process ForkPoolWorker-545:
# Process ForkPoolWorker-606:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-492:
# Process ForkPoolWorker-314:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-125:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-62:
# Process ForkPoolWorker-368:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-556:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-229:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-234:
# Process ForkPoolWorker-526:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Process ForkPoolWorker-340:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-416:
# KeyboardInterrupt
# Process ForkPoolWorker-232:
# Process ForkPoolWorker-123:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-330:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-544:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-131:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-107:
# Process ForkPoolWorker-109:
# Traceback (most recent call last):
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-266:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Process ForkPoolWorker-450:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-246:
# Traceback (most recent call last):
# Process ForkPoolWorker-501:
# Traceback (most recent call last):
# Process ForkPoolWorker-72:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-31:
# Traceback (most recent call last):
# Process ForkPoolWorker-522:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Process ForkPoolWorker-286:
# Process ForkPoolWorker-281:
# Process ForkPoolWorker-531:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-147:
# Process ForkPoolWorker-546:
# Process ForkPoolWorker-366:
# Process ForkPoolWorker-489:
# Process ForkPoolWorker-364:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-129:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-602:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Traceback (most recent call last):
# Process ForkPoolWorker-443:
# Process ForkPoolWorker-410:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Process ForkPoolWorker-182:
# Process ForkPoolWorker-420:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-562:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-167:
# Process ForkPoolWorker-92:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-184:
# Traceback (most recent call last):
# Process ForkPoolWorker-449:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
# Process ForkPoolWorker-108:
# Process ForkPoolWorker-115:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Process ForkPoolWorker-272:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-578:
# Process ForkPoolWorker-619:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-230:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-191:
# Process ForkPoolWorker-195:
# Process ForkPoolWorker-213:
# Process ForkPoolWorker-223:
# Process ForkPoolWorker-190:
# Process ForkPoolWorker-207:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-192:
# Process ForkPoolWorker-194:
# Process ForkPoolWorker-208:
# Process ForkPoolWorker-198:
# Process ForkPoolWorker-214:
# Process ForkPoolWorker-224:
# Process ForkPoolWorker-196:
# Process ForkPoolWorker-222:
# Process ForkPoolWorker-199:
# Process ForkPoolWorker-201:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# Process ForkPoolWorker-586:
# Process ForkPoolWorker-396:
# Traceback (most recent call last):
# Process ForkPoolWorker-380:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-97:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-447:
# Process ForkPoolWorker-395:
# Process ForkPoolWorker-495:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-539:
# Process ForkPoolWorker-127:
# Traceback (most recent call last):
# Process ForkPoolWorker-483:
# Process ForkPoolWorker-268:
# Process ForkPoolWorker-400:
# Process ForkPoolWorker-401:
# Process ForkPoolWorker-402:
# Process ForkPoolWorker-212:
# Process ForkPoolWorker-134:
# Traceback (most recent call last):
# Process ForkPoolWorker-157:
# Process ForkPoolWorker-237:
# Process ForkPoolWorker-231:
# Process ForkPoolWorker-215:
# Process ForkPoolWorker-511:
# Process ForkPoolWorker-551:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-145:
# Process ForkPoolWorker-417:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-144:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-558:
# Traceback (most recent call last):
# Process ForkPoolWorker-618:
# Process ForkPoolWorker-436:
# Process ForkPoolWorker-557:
# Process ForkPoolWorker-581:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-106:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-598:
# Process ForkPoolWorker-162:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-440:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-555:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-318:
# Process ForkPoolWorker-210:
# Traceback (most recent call last):
# Process ForkPoolWorker-225:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-445:
# Traceback (most recent call last):
# Process ForkPoolWorker-397:
# Process ForkPoolWorker-491:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-505:
# ...
# Process ForkPoolWorker-361:
# Process ForkPoolWorker-284:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Process ForkPoolWorker-355:
# Process ForkPoolWorker-360:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Process ForkPoolWorker-53:
# Traceback (most recent call last):
# Process ForkPoolWorker-324:
# Traceback (most recent call last):
# Process ForkPoolWorker-403:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-101:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-248:
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# Process ForkPoolWorker-357:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-457:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-610:
# Process ForkPoolWorker-277:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-362:
# Process ForkPoolWorker-409:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Process ForkPoolWorker-537:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-611:
# Process ForkPoolWorker-404:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-347:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Process ForkPoolWorker-132:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 352, in get
#     res = self._reader.recv_bytes()
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 110, in worker
#     task = get()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/queues.py", line 351, in get
#     with self._rlock:

# %%
import pickle as pkl
with open('lngE_8.pkl', 'wb') as f:
    pkl.dump(lngE, f)
# Out:
# Exception in thread Thread-757:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
# OSError: [Errno 24] Too many open files
#
# Exception ignored in: <Finalize object, dead>
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
# Exception in thread Thread-334:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
#
# Exception in thread Thread-415:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
#
# Exception in thread Thread-115:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
#
# Exception in thread Thread-376:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
# Exception ignored in: Exception in thread Thread-481:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
# Exception in thread Thread-808:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
# <Finalize object, dead>
#
#
# Exception in thread Thread-931:
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 412, in _handle_workers
#     pool._maintain_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 248, in _maintain_pool
#     self._repopulate_pool()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 241, in _repopulate_pool
#     w.start()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 112, in start
#     self._popen = self._Popen(self)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/context.py", line 277, in _Popen
#     return Popen(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 20, in __init__
#     self._launch(process_obj)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/popen_fork.py", line 69, in _launch
#     parent_r, child_w = os.pipe()
# OSError: [Errno 24] Too many open files
#
# Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
#
# Exception ignored in: Exception ignored in:     <Finalize object, dead>Exception ignored in: Exception ignored in: <Finalize object, dead><Finalize object, dead>
# <Finalize object, dead>
#
# res = self._callback(*self._args, **self._kwargs)Traceback (most recent call last):
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
# Exception ignored in: Traceback (most recent call last):
# Traceback (most recent call last):
# Exception ignored in:   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
#
# <Finalize object, dead>  File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
# <Finalize object, dead>
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
#
# res = self._callback(*self._args, **self._kwargs)Traceback (most recent call last):
#
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
# Traceback (most recent call last):
#
#           File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
# Traceback (most recent call last):
# res = self._callback(*self._args, **self._kwargs)      File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
# res = self._callback(*self._args, **self._kwargs)res = self._callback(*self._args, **self._kwargs)
#
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/util.py", line 189, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
#       File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
#
# p.terminate()  File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
#
#       File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#     p.terminate()res = self._callback(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#     self._popen.terminate()
# AttributeError: 'NoneType' object has no attribute 'terminate'
#         p.terminate()        p.terminate()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
# res = self._callback(*self._args, **self._kwargs)
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
# p.terminate()
# p.terminate()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#
#     p.terminate()
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/pool.py", line 601, in _terminate_pool
#
#     self._popen.terminate()
# AttributeError: 'NoneType' object has no attribute 'terminate'
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
#         self._popen.terminate()
# AttributeError: 'NoneType' object has no attribute 'terminate'
# self._popen.terminate()            self._popen.terminate()
# self._popen.terminate()p.terminate()AttributeError:
# 'NoneType' object has no attribute 'terminate'
#     AttributeErrorself._popen.terminate()AttributeError
#
#
#   File "/Users/gilhankim/opt/anaconda3/lib/python3.7/multiprocessing/process.py", line 124, in terminate
# : AttributeError'NoneType' object has no attribute 'terminate': : 'NoneType' object has no attribute 'terminate'
# 'NoneType' object has no attribute 'terminate'
#
#     self._popen.terminate()
# AttributeError: 'NoneType' object has no attribute 'terminate'
